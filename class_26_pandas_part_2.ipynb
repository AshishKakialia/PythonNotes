# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/weather_data.csv')

# %%
df.head(10)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df.describe(include = 'object')
# Out:
#              day event
# count          6     6
# unique         6     3
# top     1/1/2017  Rain
# freq           1     2

# %%
df.describe(include = 'all')
# Out:
#              day  temperature  windspeed event
# count          6     6.000000   6.000000     6
# unique         6          NaN        NaN     3
# top     1/1/2017          NaN        NaN  Rain
# freq           1          NaN        NaN     2
# mean         NaN    30.333333   4.666667   NaN
# std          NaN     3.829708   2.338090   NaN
# min          NaN    24.000000   2.000000   NaN
# 25%          NaN    28.750000   2.500000   NaN
# 50%          NaN    31.500000   5.000000   NaN
# 75%          NaN    32.000000   6.750000   NaN
# max          NaN    35.000000   7.000000   NaN

# %%
df = pd.read_csv('datasets/citibike_tripdata.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32428 entries, 0 to 32427
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tripduration         32428 non-null  int64
#  1   starttime            32428 non-null  object
#  2   stoptime             32428 non-null  object
#  3   start station id     32428 non-null  int64
#  4   start station name   32428 non-null  object
#  5   end station id       32428 non-null  int64
#  6   end station name     32428 non-null  object
#  7   bikeid               32428 non-null  int64
#  8   name_localizedValue  32428 non-null  object
#  9   usertype             32428 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 2.5+ MB

# %%
df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
# slicing and indexing in df

# %%
# select a particular column

df['starttime']
# Out:
# 0        2018-05-01 00:04:47
# 1        2018-05-01 01:31:10
# 2        2018-05-01 01:31:29
# 3        2018-05-01 02:03:29
# 4        2018-05-01 04:27:12
#                 ...
# 32423    2018-05-30 13:49:18
# 32424    2018-05-30 13:49:21
# 32425    2018-05-30 13:49:51
# 32426    2018-05-30 13:50:52
# 32427    2018-05-30 13:50:58
# Name: starttime, Length: 32428, dtype: object

# %%
# select 2 or more data type

df[['starttime', 'bikeid']]
# Out:
#                  starttime  bikeid
# 0      2018-05-01 00:04:47   33558
# 1      2018-05-01 01:31:10   33593
# 2      2018-05-01 01:31:29   29217
# 3      2018-05-01 02:03:29   29662
# 4      2018-05-01 04:27:12   15271
# ...                    ...     ...
# 32423  2018-05-30 13:49:18   29639
# 32424  2018-05-30 13:49:21   26301
# 32425  2018-05-30 13:49:51   29260
# 32426  2018-05-30 13:50:52   26239
# 32427  2018-05-30 13:50:58   33660
#
# [32428 rows x 2 columns]

# %%
operations

1. normal slicing

2. loc

3. iloc

# %%
# 1. normal slicing
"""
synatx - df[start:stop:step] / df[start_row_name : stop_row_name : step]

- custom indexing
- zero indexing

-it can do slicing only on rows
"""

# %%
df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
df[::2]
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# 6               577  2018-05-01 05:05:46  2018-05-01 05:15:23
# 8               395  2018-05-01 05:12:07  2018-05-01 05:18:42
# ...             ...                  ...                  ...
# 32418           340  2018-05-30 13:42:45  2018-05-30 13:48:26
# 32420           485  2018-05-30 13:44:46  2018-05-30 13:52:51
# 32422           108  2018-05-30 13:49:12  2018-05-30 13:51:00
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
#
#        start station id     start station name  end station id  \
# 0                  3639             Harborside            3199
# 2                  3194        McGinley Square            3193
# ...

# %%
df[2:11]
# Out:
#     tripduration            starttime             stoptime  start station id  \
# 2            232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3            190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4            303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5            176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# 6            577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 7            830  2018-05-01 05:11:50  2018-05-01 05:25:41              3207
# 8            395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
# 9            170  2018-05-01 05:13:52  2018-05-01 05:16:43              3206
# 10           353  2018-05-01 05:18:36  2018-05-01 05:24:29              3225
#
#        start station name  end station id end station name  bikeid  \
# 2         McGinley Square            3193     Lincoln Park   29217
# ...

# %%
df_new = df[0:6]
df_new
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
# ...

# %%
index = ['row1' , 'row2' , 'row3' , 'row4' , 'row5' , 'row6']
df_new.index = index
df_new
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
# row4              3185          City Hall            3186    Grove St PATH
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
# ...

# %%
# zero indexing
df_new[2::2]
# Out:
#       tripduration            starttime             stoptime  \
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#       start station id start station name  end station id end station name  \
# row3              3194    McGinley Square            3193     Lincoln Park
# row5              3207        Oakland Ave            3195          Sip Ave
#
#       bikeid                      name_localizedValue    usertype
# row3   29217  FREE Bonus Month with Annual Membership  Subscriber
# row5   15271                        Annual Membership  Subscriber

# %%
# custom indexing
df_new['row2'::2]
# Out:
#       tripduration            starttime             stoptime  \
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row2              3681           Grand St            3185        City Hall
# row4              3185          City Hall            3186    Grove St PATH
# row6              3194    McGinley Square            3195          Sip Ave
#
#       bikeid name_localizedValue    usertype
# row2   33593             24 Hour    Customer
# row4   29662             24 Hour    Customer
# row6   29298   Annual Membership  Subscriber

# %%
df_new
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
# row4              3185          City Hall            3186    Grove St PATH
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/tz/1bkg3flj25ld_mcgv99ct6w80000gn/T/ipykernel_25833/177581851.py in <module>
# ----> 1 df_new[['row1' , 'row2']]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
#2 . loc

"""
- it can be done both on rows as well as column
- syntax df.loc['start' : 'stop' : step , start:stop:step]
- you can only do custom indexing

"""

# %%
df_new
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
# row4              3185          City Hall            3186    Grove St PATH
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
# ...

# %%
df_new.loc[0::2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/tz/1bkg3flj25ld_mcgv99ct6w80000gn/T/ipykernel_25833/1675160056.py in <module>
# ----> 1 df_new.loc[0::2]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1140         if isinstance(key, slice):
#    1141             self._validate_key(key, axis)
# -> 1142             return self._get_slice_axis(key, axis=axis)
#    1143         elif com.is_bool_indexer(key):
#    1144             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
df_new_2 = df[0:6:]

# %%
df_new_2
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
# ...

# %%
df_new
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
# row4              3185          City Hall            3186    Grove St PATH
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
# ...

# %%
df_new.loc['row1': 'row3' , ::2]
# Out:
#       tripduration             stoptime start station name end station name  \
# row1           338  2018-05-01 00:10:25         Harborside     Newport Pkwy
# row2          1482  2018-05-01 01:55:53           Grand St        City Hall
# row3           232  2018-05-01 01:35:22    McGinley Square     Lincoln Park
#
#                           name_localizedValue
# row1                        Annual Membership
# row2                                  24 Hour
# row3  FREE Bonus Month with Annual Membership

# %%
df_new.loc[::2,'starttime':'bikeid']
# Out:
#                 starttime             stoptime  start station id  \
# row1  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# row3  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# row5  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#      start station name  end station id end station name  bikeid
# row1         Harborside            3199     Newport Pkwy   33558
# row3    McGinley Square            3193     Lincoln Park   29217
# row5        Oakland Ave            3195          Sip Ave   15271

# %%
df_new
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
# row4              3185          City Hall            3186    Grove St PATH
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
# ...

# %%
df_new.loc[['row1' , 'row3' , 'row4'], ['tripduration' , 'bikeid' , 'usertype']]
# Out:
#       tripduration  bikeid    usertype
# row1           338   33558  Subscriber
# row3           232   29217  Subscriber
# row4           190   29662    Customer

# %%
df
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
df.loc[df['tripduration']>400]
# Out:
#        tripduration            starttime             stoptime  \
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 6               577  2018-05-01 05:05:46  2018-05-01 05:15:23
# 7               830  2018-05-01 05:11:50  2018-05-01 05:25:41
# 11              704  2018-05-01 05:23:26  2018-05-01 05:35:11
# 13              428  2018-05-01 05:31:40  2018-05-01 05:38:48
# ...             ...                  ...                  ...
# 32411           873  2018-05-30 13:29:58  2018-05-30 13:44:32
# 32414           402  2018-05-30 13:35:49  2018-05-30 13:42:32
# 32417           622  2018-05-30 13:40:03  2018-05-30 13:50:26
# 32420           485  2018-05-30 13:44:46  2018-05-30 13:52:51
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
#
#        start station id     start station name  end station id  \
# 1                  3681               Grand St            3185
# 6                  3225  Baldwin at Montgomery            3186
# ...

# %%
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 32423    False
# 32424    False
# 32425    False
# 32426     True
# 32427    False
# Name: tripduration, Length: 32428, dtype: bool

# %%
# give me all the datat user type is 'subscriber'
df.loc[df['usertype']=='Subscriber']
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# 5               176  2018-05-01 04:37:05  2018-05-01 04:40:01
# 6               577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id     start station name  end station id  \
# 0                  3639             Harborside            3199
# 2                  3194        McGinley Square            3193
# ...

# %%
usertype is sub and bikeid > 30000

logical - & , |  , ~

# %%
df.loc[(df['usertype'] ==  'Subscriber') & (df['bikeid'] > 3000)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/tz/1bkg3flj25ld_mcgv99ct6w80000gn/T/ipykernel_25833/316066830.py in <module>
# ----> 1 df.loc[(df['usertype'] ==  'Subscriber') and (df['bikeid'] > 3000)]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
3. iloc
"""
- it can do slicing both on index as well column
- zero indexing
- syntax df.iloc['start' : 'stop' : step , start:stop:step]

"""

# %%
df_new.iloc['row1':'row2']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/tz/1bkg3flj25ld_mcgv99ct6w80000gn/T/ipykernel_25833/28754856.py in <module>
# ----> 1 df_new.iloc['row1':'row2']
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1541
#    1542         if isinstance(key, slice):
# -> 1543             return self._get_slice_axis(key, axis=axis)
#    1544
#    1545         if is_iterator(key):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
# ...

# %%
df_new.iloc[1:3]
# Out:
#       tripduration            starttime             stoptime  \
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
#
#       start station id start station name  end station id end station name  \
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
#
#       bikeid                      name_localizedValue    usertype
# row2   33593                                  24 Hour    Customer
# row3   29217  FREE Bonus Month with Annual Membership  Subscriber

# %%
df_new
# Out:
#       tripduration            starttime             stoptime  \
# row1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#       start station id start station name  end station id end station name  \
# row1              3639         Harborside            3199     Newport Pkwy
# row2              3681           Grand St            3185        City Hall
# row3              3194    McGinley Square            3193     Lincoln Park
# row4              3185          City Hall            3186    Grove St PATH
# row5              3207        Oakland Ave            3195          Sip Ave
# row6              3194    McGinley Square            3195          Sip Ave
#
# ...

# %%
df_new.iloc[1:3 , 2:5]
# Out:
#                  stoptime  start station id start station name
# row2  2018-05-01 01:55:53              3681           Grand St
# row3  2018-05-01 01:35:22              3194    McGinley Square

# %%
df_new.iloc[df['tripduration']>300]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/tz/1bkg3flj25ld_mcgv99ct6w80000gn/T/ipykernel_25833/2389686619.py in <module>
# ----> 1 df_new.iloc[df['tripduration']>300]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1550
#    1551         if com.is_bool_indexer(key):
# -> 1552             self._validate_key(key, axis)
#    1553             return self._getbool_axis(key, axis=axis)
#    1554
#
# ...

# %%
normal - rows
- zero / custom


loc - both
- custom
- filter

iloc - both
- zero

# %%
# addition and deletion in the dataframe

# %%
df = pd.read_csv('datasets/imdb_rating.csv')

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
# adding a column
df['actors'] = 'the rock'

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration    actors
# 0       142  the rock
# 1       175  the rock
# 2       200  the rock
# 3       152  the rock
# 4       154  the rock
# 5        96  the rock
# ...

# %%
df['actors'] = range(0,10)

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration  actors
# 0       142       0
# 1       175       1
# 2       200       2
# 3       152       3
# 4       154       4
# 5        96       5
# ...

# %%
# insert

df.insert(1,'actorss','abc')

# %%
df
# Out:
#    star_rating actorss                                          title  \
# 0          9.3     abc                       The Shawshank Redemption
# 1          9.2     abc                                  The Godfather
# 2          9.1     abc                         The Godfather: Part II
# 3          9.0     abc                                The Dark Knight
# 4          8.9     abc                                   Pulp Fiction
# 5          8.9     abc                                   12 Angry Men
# 6          8.9     abc                 The Good, the Bad and the Ugly
# 7          8.9     abc  The Lord of the Rings: The Return of the King
# 8          8.9     abc                               Schindler's List
# 9          8.9     abc                                     Fight Club
#
#        genre  duration  actors
# 0      Crime       142       0
# 1      Crime       175       1
# 2      Crime       200       2
# 3     Action       152       3
# 4      Crime       154       4
# ...

# %%
df = pd.read_csv('datasets/imdb_rating.csv')

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
df.loc[df['duration']==100].index[0]
# Out:
# 4

# %%
df.loc[df.loc[df['duration']==100].index[0] , 'duration'] = 200

# %%
df
# Out:
#     star_rating                                          title      genre  \
# 0           9.3                       The Shawshank Redemption      Crime
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.0                                The Dark Knight     Action
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          9.8                                            abc      drama
#
#     duration
# 0        142
# 1        175
# 2        200
# 3        152
# ...

# %%
# adding a row

df.loc[len(df)] = [9.8 , 'abc' , 'drama' , 120]

# %%
df
# Out:
#     star_rating                                          title      genre  \
# 0           9.3                       The Shawshank Redemption      Crime
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.0                                The Dark Knight     Action
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          9.8                                            abc      drama
#
#     duration
# 0        142
# 1        175
# 2        200
# 3        152
# ...

# %%
df.append({'star_rating' : 42 , 'title' : 'abc' , 'genre': 140 , 'duration': 200} , ignore_index = True)
# Out:
#     star_rating                                          title      genre  \
# 0           9.3                       The Shawshank Redemption      Crime
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.0                                The Dark Knight     Action
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          9.8                                            abc      drama
# 11         42.0                                            abc        140
#
# ...

# %%
# drop

df.drop(columns=['duration'] , inplace = True)

# %%
df
# Out:
#     star_rating                                          title      genre
# 0           9.3                       The Shawshank Redemption      Crime
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.0                                The Dark Knight     Action
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          9.8                                            abc      drama

# %%
df.drop(index=0 , inplace = True)

# %%
df
# Out:
#     star_rating                                          title      genre
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.0                                The Dark Knight     Action
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          9.8                                            abc      drama

# %%
# sorting

df.sort_values(by='star_rating')
# Out:
#     star_rating                                          title      genre
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 3           9.0                                The Dark Knight     Action
# 2           9.1                         The Godfather: Part II      Crime
# 1           9.2                                  The Godfather      Crime
# 10          9.8                                            abc      drama

# %%
df.sort_values(by='genre')
# Out:
#     star_rating                                          title      genre
# 3           9.0                                The Dark Knight     Action
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 9           8.9                                     Fight Club      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 10          9.8                                            abc      drama

# %%
df.sort_values(by=['genre' , 'star_rating'])
# Out:
#     star_rating                                          title      genre
# 3           9.0                                The Dark Knight     Action
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 4           8.9                                   Pulp Fiction      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 1           9.2                                  The Godfather      Crime
# 5           8.9                                   12 Angry Men      Drama
# 9           8.9                                     Fight Club      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 10          9.8                                            abc      drama

# %%
df.sort_values(by=['genre' , 'star_rating'] , ascending=False)
# Out:
#     star_rating                                          title      genre
# 10          9.8                                            abc      drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 5           8.9                                   12 Angry Men      Drama
# 9           8.9                                     Fight Club      Drama
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 4           8.9                                   Pulp Fiction      Crime
# 8           8.9                               Schindler's List  Biography
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 3           9.0                                The Dark Knight     Action
